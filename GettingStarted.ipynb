# %% [markdown]
# ## Isocenter
#
# **A Python DICOM Object Model and Redaction Toolkit.**
#
# Isocenter provides a high-performance, object-oriented interface for managing, analyzing, and de-identifying DICOM datasets. It is designed for large-scale ingestion, precise pixel redaction, and strict PHI compliance.
#
# 1. **Ingest**: Load raw data into the managed session index.
# 2. **Examine**: Inventory the cohort and equipment.
# 3. **Configure**: Define privacy tags and redaction rules.
# 4. **Audit (Target)**: Measure PHI risks against the configuration.
# 5. **Backup**: (Optional) Securely lock original identities for reversibility.
# 6. **Anonymize**: Apply remediation to metadata (in-memory).
# 7. **Redact**: Scrub pixel data for specific machines (in-memory).
# 8. **Verify**: Re-audit the session to ensure a clean state.
# 9. **Report**: Generate a signed Compliance Report (Manifest, Exceptions, Audit Trail).
# 10. **Export**: Write clean DICOM files to disk.

# %%
# %pip install --force-reinstall "git+https://github.com/kvnlng/Isocenter.git"
# Out:
# Collecting git+https://github.com/kvnlng/Isocenter.git
#   Cloning https://github.com/kvnlng/Isocenter.git to /private/var/folders/9_/t_m12zps0xx_3k059_29tbj40000gn/T/pip-req-build-40nvr92e
#   Running command git clone --filter=blob:none --quiet https://github.com/kvnlng/Isocenter.git /private/var/folders/9_/t_m12zps0xx_3k059_29tbj40000gn/T/pip-req-build-40nvr92e
#   Resolved https://github.com/kvnlng/Isocenter.git to commit 29abe16c28dc1270cc20d4b75fff3466b573a400
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pydicom>=2.4.0 (from isocenter==0.5.3)
#   Using cached pydicom-3.0.1-py3-none-any.whl.metadata (9.4 kB)
# Collecting numpy>=1.20.0 (from isocenter==0.5.3)
#   Using cached numpy-2.4.1-cp314-cp314t-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting tqdm>=4.65.0 (from isocenter==0.5.3)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting cryptography>=41.0.0 (from isocenter==0.5.3)
#   Using cached cryptography-46.0.3-cp314-cp314t-macosx_10_9_universal2.whl.metadata (5.7 kB)
# Collecting pandas>=2.0.0 (from isocenter==0.5.3)
#   Using cached pandas-2.3.3-cp314-cp314t-macosx_11_0_arm64.whl.metadata (91 kB)
# Collecting pyarrow>=14.0.0 (from isocenter==0.5.3)
#   Using cached pyarrow-22.0.0-cp314-cp314t-macosx_12_0_arm64.whl.metadata (3.2 kB)
# Collecting PyYAML>=6.0 (from isocenter==0.5.3)
#   Using cached pyyaml-6.0.3-cp314-cp314t-macosx_11_0_arm64.whl.metadata (2.4 kB)
# Collecting pillow>=10.0.0 (from isocenter==0.5.3)
#   Using cached pillow-12.1.0-cp314-cp314t-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting imagecodecs>=2023.0.0 (from isocenter==0.5.3)
#   Using cached imagecodecs-2026.1.14-cp314-cp314t-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting cffi>=2.0.0 (from cryptography>=41.0.0->isocenter==0.5.3)
#   Using cached cffi-2.0.0-cp314-cp314t-macosx_11_0_arm64.whl.metadata (2.6 kB)
# Collecting pycparser (from cffi>=2.0.0->cryptography>=41.0.0->isocenter==0.5.3)
#   Using cached pycparser-2.23-py3-none-any.whl.metadata (993 bytes)
# Collecting python-dateutil>=2.8.2 (from pandas>=2.0.0->isocenter==0.5.3)
#   Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas>=2.0.0->isocenter==0.5.3)
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=2.0.0->isocenter==0.5.3)
#   Using cached tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas>=2.0.0->isocenter==0.5.3)
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Using cached cryptography-46.0.3-cp314-cp314t-macosx_10_9_universal2.whl (7.2 MB)
# Using cached cffi-2.0.0-cp314-cp314t-macosx_11_0_arm64.whl (185 kB)
# Using cached imagecodecs-2026.1.14-cp314-cp314t-macosx_11_0_arm64.whl (11.0 MB)
# Using cached numpy-2.4.1-cp314-cp314t-macosx_14_0_arm64.whl (5.3 MB)
# Using cached pandas-2.3.3-cp314-cp314t-macosx_11_0_arm64.whl (11.4 MB)
# Using cached pillow-12.1.0-cp314-cp314t-macosx_11_0_arm64.whl (4.7 MB)
# Using cached pyarrow-22.0.0-cp314-cp314t-macosx_12_0_arm64.whl (34.4 MB)
# Using cached pydicom-3.0.1-py3-none-any.whl (2.4 MB)
# Using cached python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Using cached pyyaml-6.0.3-cp314-cp314t-macosx_11_0_arm64.whl (183 kB)
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached pycparser-2.23-py3-none-any.whl (118 kB)
# Building wheels for collected packages: isocenter
#   Building wheel for isocenter (pyproject.toml) ... done
#   Created wheel for isocenter: filename=isocenter-0.5.3-py3-none-any.whl size=78358 sha256=00c588339a5d3779117007958308716e42e366cec024c6edcedaa213b3c454e4
#   Stored in directory: /private/var/folders/9_/t_m12zps0xx_3k059_29tbj40000gn/T/pip-ephem-wheel-cache-g4k43eya/wheels/05/e3/e4/9ce4b5bd9557d17da46ca09b53f385a7710ac92f29ca9b201e
# Successfully built isocenter
# Installing collected packages: pytz, tzdata, tqdm, six, PyYAML, pydicom, pycparser, pyarrow, pillow, numpy, python-dateutil, imagecodecs, cffi, pandas, cryptography, isocenter
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2025.3
#     Uninstalling tzdata-2025.3:
#       Successfully uninstalled tzdata-2025.3
#   Attempting uninstall: tqdm╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Found existing installation: tqdm 4.67.10m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Uninstalling tqdm-4.67.1:;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#       Successfully uninstalled tqdm-4.67.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#   Attempting uninstall: six;2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Found existing installation: six 1.17.0━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Uninstalling six-1.17.0:2;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#       Successfully uninstalled six-1.17.0╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#   Attempting uninstall: PyYAML249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Found existing installation: PyYAML 6.0.3m━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Uninstalling PyYAML-6.0.3:249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#       Successfully uninstalled PyYAML-6.0.3━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#   Attempting uninstall: pydicom49;38;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Found existing installation: pydicom 3.0.1━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━  1/16 [tzdata]
#     Uninstalling pydicom-3.0.1:━━╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#       Successfully uninstalled pydicom-3.0.138;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#   Attempting uninstall: pycparser╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#     Found existing installation: pycparser 2.23114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#     Uninstalling pycparser-2.23:m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#       Successfully uninstalled pycparser-2.238;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#   Attempting uninstall: pyarrow0m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#     Found existing installation: pyarrow 22.0.0114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#     Uninstalling pyarrow-22.0.0:m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#       Successfully uninstalled pyarrow-22.0.08;114m╸━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/16 [pydicom]
#   Attempting uninstall: pillow━━━━━━━━╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [pyarrow]
#     Found existing installation: pillow 12.1.049;38;114m╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [pyarrow]
#     Uninstalling pillow-12.1.0:━━━╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [pyarrow]
#       Successfully uninstalled pillow-12.1.0;249;38;114m╸━━━━━━━━━━━━━━━━━━━━━━  7/16 [pyarrow]
#   Attempting uninstall: numpy━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  8/16 [pillow]row]
#     Found existing installation: numpy 2.4.18;5;237m╺━━━━━━━━━━━━━━━━━━━  8/16 [pillow]
#     Uninstalling numpy-2.4.1:━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  8/16 [pillow]
#       Successfully uninstalled numpy-2.4.1╺━━━━━━━━━━━━━━━━━━━  8/16 [pillow]
#   Attempting uninstall: python-dateutil━━━━╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#     Found existing installation: python-dateutil 2.9.0.post0m╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#     Uninstalling python-dateutil-2.9.0.post0:38;2;249;38;114m╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#       Successfully uninstalled python-dateutil-2.9.0.post014m╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#   Attempting uninstall: imagecodecs━━━━╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#     Found existing installation: imagecodecs 2026.1.1438;114m╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#     Uninstalling imagecodecs-2026.1.14:╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#       Successfully uninstalled imagecodecs-2026.1.149;38;114m╸━━━━━━━━━━━━━━━━━  9/16 [numpy]
#   Attempting uninstall: cffi━━━━━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 11/16 [imagecodecs]
#     Found existing installation: cffi 2.0.0━╸━━━━━━━━━━━━ 11/16 [imagecodecs]
#     Uninstalling cffi-2.0.0:━━━━━━━━━━━━━━━━╸━━━━━━━━━━━━ 11/16 [imagecodecs]
#       Successfully uninstalled cffi-2.0.0━━━╸━━━━━━━━━━━━ 11/16 [imagecodecs]
#   Attempting uninstall: pandas━━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━ 12/16 [pandas]ecodecs]
#     Found existing installation: pandas 2.3.3━━╺━━━━━━━━━ 12/16 [pandas]
#     Uninstalling pandas-2.3.3:━━━━━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 13/16 [pandas]
#       Successfully uninstalled pandas-2.3.3━━━━━━╸━━━━━━━ 13/16 [pandas]
#   Attempting uninstall: cryptography━━━━━━━━━━━━━━━━━╸━━━━━━━ 13/16 [pandas]
#     Found existing installation: cryptography 46.0.3m╸━━━━━━━ 13/16 [pandas]
#     Uninstalling cryptography-46.0.3:━━━━━━━━━━━━╸━━━━━━━ 13/16 [pandas]
#       Successfully uninstalled cryptography-46.0.3╸━━━━━━━ 13/16 [pandas]
#   Attempting uninstall: isocenter━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 13/16 [pandas]
#     Found existing installation: isocenter 0.5.3━━━━╸━━━━━━━ 13/16 [pandas]
#     Uninstalling isocenter-0.5.3:━━━━━━━━━━━━━━━━━━━╸━━━━━━━ 13/16 [pandas]
#       Successfully uninstalled isocenter-0.5.3━━━━━━╸━━━━━━━ 13/16 [pandas]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16/16 [isocenter]━━━━━ 13/16 [pandas]
# Successfully installed PyYAML-6.0.3 cffi-2.0.0 cryptography-46.0.3 isocenter-0.5.3 imagecodecs-2026.1.14 numpy-2.4.1 pandas-2.3.3 pillow-12.1.0 pyarrow-22.0.0 pycparser-2.23 pydicom-3.0.1 python-dateutil-2.9.0.post0 pytz-2025.2 six-1.17.0 tqdm-4.67.1 tzdata-2025.3
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Initialize a Session
#
# Isocenter uses a **persistent session** to manage your workflow. Unlike scripts that run once and forget, a Session creates a local SQLite database (`isocenter.db`) to index your data. This allows you to pause, resume, and audit your work without re-scanning thousands of files.

# %%
from isocenter import Session
session = Session("cohort.db")
# Out:
# Initializing new session at cohort.db...

# %% [markdown]
# ### Ingest & Examine
#
# Ingestion builds a lightweight **metadata index** of your DICOM files. Isocenter scans your folders recursively, extracting patient/study/series information into the database *without moving or modifying your original files*. It is resilient to nested directories and non-DICOM clutter.

# %%
session.ingest("comprehensive_dicoms")
session.save() # Persist the index to disk
# Out:
# Ingesting from 'comprehensive_dicoms'...
# Ingesting: 100%|█████████████████████████████████████████████████████████████████████████████████████████| 140/140 [00:00<00:00, 516.75it/s]
# Ingestion complete. Saved session state.
# Summary:
#   - 140 Patients
#   - 140 Studies
#   - 140 Series
#   - 140 Instances

# %%
# Print a summary of the cohort and equipment
session.examine()
# Out:
# Inventory Summary:
#  Patients:  140
#  Studies:   140
#  Series:    140
#  Instances: 140
#
# Equipment Inventory:
#  - Agfa - CR 30-X (Count: 5)
#  - Agfa - DX-D (Count: 5)
#  - Carestream - Classic (Count: 5)
#  - Carestream - DRX (Count: 5)
#  - Fuji - FCR (Count: 5)
#  - Fuji - FDR (Count: 5)
#  - GE - Discovery (Count: 5)
#  - GE - Discovery MI (Count: 5)
#  - GE - Innova (Count: 5)
#  - GE - NM 830 (Count: 5)
#  - GE - Precision (Count: 5)
#  - GE - Revolution (Count: 5)
#  - GE - Senographe (Count: 5)
#  - GE - Voluson (Count: 5)
#  - Isocenter - ReportSystem (Count: 5)
#  - Isocenter - Test (Count: 5)
#  - Generic - ScreenCapture (Count: 5)
#  - Hologic - Selenia (Count: 5)
#  - Philips - Brilliance (Count: 5)
#  - Philips - EPIQ (Count: 5)
#  - Philips - Ingenia (Count: 5)
#  - Siemens - Acuson (Count: 5)
#  - Siemens - Artis (Count: 5)
#  - Siemens - Biograph (Count: 5)
#  - Siemens - Luminos (Count: 5)
#  - Siemens - Magnetom (Count: 5)
#  - Siemens - Somatom (Count: 5)
#  - Siemens - Symbia (Count: 5)

# %% [markdown]
# ### Create Configuration
#
# Before changing anything, define your privacy rules.
#
# Use `create_config` to generate a scaffolding based on your inventory.

# %%
# Create a default configuration file
session.create_config("config.yaml")

# Load the configuration (rules, tags, jitter)
session.load_config("config.yaml")
# Out:
# Scaffolded Unified Config to config.yaml
# Loading configuration from config.yaml...
# Configuration Loaded:
#  - 140 Machine Redaction Rules
#  - 29 PHI Tags
#  - Date Jitter: -365 to -1 days
#  - Remove Private Tags: True
# Tip: Run .audit() to check PHI, or .redact_pixels() to apply redaction.

# %%
# Run an audit to find PHI
report = session.audit() 
session.save_analysis(report)

print(f"Found {len(report)} potential PHI issues.")
# Out:
# Scanning PHI: 100%|███████████████████████████████████████████████████████████████████████████████████| 140/140 [00:00<00:00, 246931.27it/s]
# Found 1960 potential PHI issues.

# %% [markdown]
# ### Backup Identity (Optional)
#
# To enable reversible anonymization, generate a cryptographic key and "lock" the original patient identities into a secure, encrypted DICOM tag. This must be done *before* anonymization.

# %%
# Enable encryption (generates 'isocenter.key')
session.enable_reversible_anonymization()

# cryptographically lock identities for all patients found in the audit
# Optional: Specify custom tags to preserve (defaults to Name, ID, DOB, Sex, Accession)
# session.lock_identities(report, tags_to_lock=["0010,0010", "0010,0020", "0010,0030"])
session.lock_identities(report)

session.save()
# Out:
# Locking Identities: 100%|█████████████████████████████████████████████████████████████████████████| 140/140 [00:00<00:00, 11190.14patient/s]

# %% [markdown]
# Isocenter supports **Exploratory Data Analysis (EDA)**. You can interrogate your cohort using Pandas and perform targeted exports based on metadata criteria.

# %%
df = session.export_dataframe(expand_metadata=True)
df.loc[df.Modality == 'CT', ['PatientID', 'PatientName']][0:10]
# Out:
# <frozen importlib._bootstrap>:491: RuntimeWarning: The global interpreter lock (GIL) has been enabled to load module 'pandas._libs.pandas_parser', which has not declared that it can run safely without the GIL. To override this behavior and keep the GIL disabled (at your own risk), run with PYTHON_GIL=0 or -Xgil=0.
# Exported metadata to export_metadata.csv
#     PatientID        PatientName
# 0   PID-42589       Pierce^Glenn
# 21  PID-89664        Ellis^David
# 27  PID-00467  Anderson^Jennifer
# 33  PID-48145        Smith^Aaron
# 36  PID-37610       Murphy^Cindy
# 38  PID-84046      Miller^Amanda
# 46  PID-91157      Welch^Leonard
# 47  PID-85557        Brandt^Mike
# 61  PID-58693     Adams^Jennifer
# 80  PID-20628    Rivera^Clarence

# %% [markdown]
# **Anonymize**: Strips or replaces metadata tags (PatientID, Names, Dates) based on your config.

# %%
# Apply metadata remediation (anonymization) using the findings
session.anonymize(report)
session.save()
# Out:
# Anonymizing Metadata: 100%|█████████████████████████████████████████████████████████████████████| 1960/1960 [00:00<00:00, 48105.16finding/s]
# Anonymized/Remediated None tags according to policy.

# %%
df = session.export_dataframe(expand_metadata=True)
df.loc[df.Modality == 'CT', ['PatientID', 'PatientName']][0:10]
# Out:
# Exported metadata to export_metadata.csv
#             PatientID PatientName
# 0   ANON_8c1c7e63cdec  ANONYMIZED
# 21  ANON_0d373fb19710  ANONYMIZED
# 27  ANON_0e295da9c9c3  ANONYMIZED
# 33  ANON_20390a10b4cc  ANONYMIZED
# 36  ANON_34d8b3092e05  ANONYMIZED
# 38  ANON_6de36b3bddc9  ANONYMIZED
# 46  ANON_894a95a83c29  ANONYMIZED
# 47  ANON_25923c79f1b5  ANONYMIZED
# 61  ANON_e73e8b4ea3c3  ANONYMIZED
# 80  ANON_dec057f22ceb  ANONYMIZED

# %% [markdown]
# ### Recover Identity (Optional)
#
# If you have a valid key (`isocenter.key`) and need to retrieve the original identity of an anonymized patient:

# %%
def recover(anon):
    session.recover_patient_identity(anon.PatientID, restore=True)

df.apply(recover, axis=1)
session.save()

# %%
df = session.export_dataframe(expand_metadata=True)
df.loc[df.Modality == 'CT', ['PatientID', 'PatientName']][0:10]

# %% [markdown]
# **Redact**: Loads pixel data and scrubs burned-in PHI from defined regions.

# %%
# Apply pixel redaction rules (requires config to be loaded)
session.redact()
# Out:
# WARNING: No matching images found for any loaded rules.
# No matching images found for any loaded rules.

# %% [markdown]
# **Export**: The final "Gatekeeper". Writes clean files to a new directory. Setting `safe=True` ensures the export halts if any verification checks fail (e.g., corrupt images or missing codecs).

# %%
df = session.export_dataframe(expand_metadata=True)
cohort_df = df[df.Modality == 'CT']
# Export only safe (clean) data to a new folder
# Compression="j2k" optionally compresses output to JPEG 2000
session.export("export_clean", subset=cohort_df, safe=True, compression="j2k")
# Out:
# Exported metadata to export_metadata.csv
# Scanning PHI: 100%|██████████████████████████████████████████████████████████████████████████████████████| 140/140 [00:00<00:00, 670.74it/s]
# Preparing export plan...
# Saving pending changes to free memory...
# Releasing Memory: 100%|█████████████████████████████████████████████████████████████████████████████| 140/140 [00:00<00:00, 2150925.13img/s]
# Memory Cleanup: Released 140 images from RAM.
# Exporting 15 images from 140 patients...
# Exporting: 100%|████████████████████████████████████████████████████████████████████████████████████████████| 15/15 [00:00<00:00, 17.28it/s]
# Done.

# %% [markdown]
# ### Compliance Report
#
# Generate single-step, audit-ready Markdown reports for HIPAA/GDPR documentation. Reports include:
#
# - **Cohort Manifest**: Summary of all processed patients/studies.
# - **Audit Trail**: Aggregated counts of every action (Anonymize, Redact, Export).
# - **Exceptions**: Explicit listing of any warnings or errors encountered.
# - **Validation Status**: Automatic `PASS`/`REVIEW_REQUIRED` grading.

# %%
# Generate a Markdown report
session.generate_report("compliance_report.md")

# %%
from IPython.display import Markdown, display

with open('compliance_report.md', 'r', encoding='utf-8') as f:
    content = f.read()
display(Markdown(content))

# %%
session.generate_manifest("manifest.html", format="html")

# %%
session.generate_manifest("manifest.json", format="json")
